# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
import jupyter_beeper
import time

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('Model/model_last.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-04-15 12:39:11.702455: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# startt  web cam
cap = cv2.VideoCapture(0) # for webcam
# cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.63602483
# user not wearing mask - prob =  0.66395026
# user not wearing mask - prob =  0.68848115
# user not wearing mask - prob =  0.62695307
# user not wearing mask - prob =  0.6581282
# user not wearing mask - prob =  0.6862533
# user not wearing mask - prob =  0.67827237
# user not wearing mask - prob =  0.6673814
# user not wearing mask - prob =  0.69330776
# user not wearing mask - prob =  0.6127394
# user not wearing mask - prob =  0.6335139
# user not wearing mask - prob =  0.5862979
# user not wearing mask - prob =  0.63753283
# user not wearing mask - prob =  0.61968005
# user not wearing mask - prob =  0.62277716
# user not wearing mask - prob =  0.5469499
# user not wearing mask - prob =  0.5776956
# user not wearing mask - prob =  0.05185974
# user not wearing mask - prob =  0.10925238
# user not wearing mask - prob =  0.098584935
# user not wearing mask - prob =  0.078956045
# user not wearing mask - prob =  0.08637264
# user not wearing mask - prob =  0.07012781
# user not wearing mask - prob =  0.08780112
# user not wearing mask - prob =  0.068216674
# user not wearing mask - prob =  0.0398479
# user not wearing mask - prob =  0.07103725
# user not wearing mask - prob =  0.055169944
# user not wearing mask - prob =  0.0432845
# user not wearing mask - prob =  0.0504011
# user not wearing mask - prob =  0.13485815
# user not wearing mask - prob =  0.5936908
# user not wearing mask - prob =  0.7616561
# user not wearing mask - prob =  0.75001514
# user not wearing mask - prob =  0.83595335
# user not wearing mask - prob =  0.8074003
# user not wearing mask - prob =  0.81784874
# user not wearing mask - prob =  0.8358635
# user not wearing mask - prob =  0.8645801
# user not wearing mask - prob =  0.8851329
# user not wearing mask - prob =  0.8741414
# user not wearing mask - prob =  0.8997797
# user not wearing mask - prob =  0.87003
# user not wearing mask - prob =  0.87976044
# user not wearing mask - prob =  0.8849666
# user not wearing mask - prob =  0.89787096
# user not wearing mask - prob =  0.91920817
# user not wearing mask - prob =  0.88384694
# user not wearing mask - prob =  0.8624424
# user not wearing mask - prob =  0.8863484
# user not wearing mask - prob =  0.84064937
# user not wearing mask - prob =  0.87454295
# user not wearing mask - prob =  0.84733605
# user not wearing mask - prob =  0.8284145
# user not wearing mask - prob =  0.7726956

# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('Model/model_last.h5', compile=False) # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200
# Out:
# 2022-04-15 13:03:23.303445: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
cap = cv2.VideoCapture(0) # for webcam
# cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.20366547
# user not wearing mask - prob =  0.1926956
# user not wearing mask - prob =  0.26354375
# user not wearing mask - prob =  0.23898405
# user not wearing mask - prob =  0.25357088
# user not wearing mask - prob =  0.23181158
# user not wearing mask - prob =  0.21737117
# user not wearing mask - prob =  0.24339738
# user not wearing mask - prob =  0.2639729
# user not wearing mask - prob =  0.32140437
# user not wearing mask - prob =  0.2581354
# user not wearing mask - prob =  0.24502654
# user not wearing mask - prob =  0.306746
# user not wearing mask - prob =  0.25912008
# user not wearing mask - prob =  0.45553535
# user not wearing mask - prob =  0.91562456
# user not wearing mask - prob =  0.77804035
# user not wearing mask - prob =  0.7260264
# user not wearing mask - prob =  0.69189256
# user not wearing mask - prob =  0.6532849
# user not wearing mask - prob =  0.72285926
# user not wearing mask - prob =  0.80951506
# user not wearing mask - prob =  0.8272836
# user not wearing mask - prob =  0.9661971
# user not wearing mask - prob =  0.9682533
# user not wearing mask - prob =  0.95326847
# user not wearing mask - prob =  0.9665527
# user not wearing mask - prob =  0.96814984
# user not wearing mask - prob =  0.7789081
# user not wearing mask - prob =  0.9755702
# user not wearing mask - prob =  0.9681496
# user not wearing mask - prob =  0.9610756
# user not wearing mask - prob =  0.9495967
# user not wearing mask - prob =  0.96138376
# user not wearing mask - prob =  0.968312
# user not wearing mask - prob =  0.96652925
# user not wearing mask - prob =  0.9622443
# user not wearing mask - prob =  0.9574093
# user not wearing mask - prob =  0.73798466
# user not wearing mask - prob =  0.96439683
# user not wearing mask - prob =  0.9610655
# user not wearing mask - prob =  0.64514154
# user not wearing mask - prob =  0.96037066
# user not wearing mask - prob =  0.96121955
# user not wearing mask - prob =  0.95172924
# user not wearing mask - prob =  0.9236634
# user not wearing mask - prob =  0.916632
# user not wearing mask - prob =  0.8928594
# user not wearing mask - prob =  0.8996422
# user not wearing mask - prob =  0.9114775
# user not wearing mask - prob =  0.9084005
# user not wearing mask - prob =  0.9364101
# user not wearing mask - prob =  0.9460474
# user not wearing mask - prob =  0.95352376
# user not wearing mask - prob =  0.946561
# user not wearing mask - prob =  0.93781614
# user not wearing mask - prob =  0.9104032
# user not wearing mask - prob =  0.2333419
# user not wearing mask - prob =  0.24075077
# user not wearing mask - prob =  0.24132875
