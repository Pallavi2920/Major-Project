# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/pallavi.gtide.co/opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('Model/model_last.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200
# Out:
# 2022-04-15 15:35:40.047175: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('model/model_last.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
cap = cv2.VideoCapture(0) # for webcam
#cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        elif pred==1:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
            
        elif pred==2:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/mask_worn_incorrectly/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.9848475
# user not wearing mask - prob =  0.99154586
# user not wearing mask - prob =  0.98773414
# user not wearing mask - prob =  0.98618686
# user not wearing mask - prob =  0.986997
# user not wearing mask - prob =  0.9850883
# user not wearing mask - prob =  0.9879731
# user not wearing mask - prob =  0.9896554
# user not wearing mask - prob =  0.9920488
# user not wearing mask - prob =  0.99182653
# user not wearing mask - prob =  0.9929616
# user not wearing mask - prob =  0.9931764
# user not wearing mask - prob =  0.99185455
# user not wearing mask - prob =  0.99431276
# user not wearing mask - prob =  0.9955538
# user not wearing mask - prob =  0.9950276
# user not wearing mask - prob =  0.9968867
# user not wearing mask - prob =  0.9920637
# user not wearing mask - prob =  0.99477357
# user not wearing mask - prob =  0.99442947
# user not wearing mask - prob =  0.99351406
# user not wearing mask - prob =  0.99411994
# user not wearing mask - prob =  0.9948602
# user not wearing mask - prob =  0.9917936
# user not wearing mask - prob =  0.99121326
# user not wearing mask - prob =  0.99454355
# user not wearing mask - prob =  0.99201465
# user not wearing mask - prob =  0.9907843
# user not wearing mask - prob =  0.9938737
# user not wearing mask - prob =  0.9977404
# user not wearing mask - prob =  0.8487012
# user not wearing mask - prob =  0.9668716
# user not wearing mask - prob =  0.8722236
# user not wearing mask - prob =  0.92982
# user not wearing mask - prob =  0.90915555
# user not wearing mask - prob =  0.8518843
# user not wearing mask - prob =  0.99914896
# user not wearing mask - prob =  0.8288348
# user not wearing mask - prob =  0.9821362
# user not wearing mask - prob =  0.99218583
# user not wearing mask - prob =  0.9273098
# user not wearing mask - prob =  0.9994043
# user not wearing mask - prob =  0.77816755
# user not wearing mask - prob =  0.967837
# user not wearing mask - prob =  0.84431857
# user not wearing mask - prob =  0.9773161
# user not wearing mask - prob =  0.99975365
# user not wearing mask - prob =  0.82281804
# user not wearing mask - prob =  0.88754296
# user not wearing mask - prob =  0.98653746
# user not wearing mask - prob =  0.992863
# user not wearing mask - prob =  0.9858973
# user not wearing mask - prob =  0.9898226
# user not wearing mask - prob =  0.9251455
# user not wearing mask - prob =  0.9868744
# user not wearing mask - prob =  0.91163045
# user not wearing mask - prob =  0.98896873
# user not wearing mask - prob =  0.99345315
# user not wearing mask - prob =  0.9060808
# user not wearing mask - prob =  0.8833678
# user not wearing mask - prob =  0.99404436
# user not wearing mask - prob =  0.9990778
# user not wearing mask - prob =  0.9915383
# user not wearing mask - prob =  0.9926587
# user not wearing mask - prob =  0.9304432
# user not wearing mask - prob =  0.9157989
# user not wearing mask - prob =  0.9917251
# user not wearing mask - prob =  0.90647507
# user not wearing mask - prob =  0.9911883
# user not wearing mask - prob =  0.8778622
# user not wearing mask - prob =  0.993529
# user not wearing mask - prob =  0.8923303
# user not wearing mask - prob =  0.99298894
# user not wearing mask - prob =  0.89757204
# user not wearing mask - prob =  0.9890616
# user not wearing mask - prob =  0.89136654
# user not wearing mask - prob =  0.92875713
# user not wearing mask - prob =  0.99224126
# user not wearing mask - prob =  0.92427033
# user not wearing mask - prob =  0.9899676
# user not wearing mask - prob =  0.99133235
# user not wearing mask - prob =  0.9913284
# user not wearing mask - prob =  0.90050215
# user not wearing mask - prob =  0.8997128
# user not wearing mask - prob =  0.99004656
# user not wearing mask - prob =  0.99160844
# user not wearing mask - prob =  0.9920839
# user not wearing mask - prob =  0.9226801
# user not wearing mask - prob =  0.9879337
# user not wearing mask - prob =  0.90199465
# user not wearing mask - prob =  0.90022105
# user not wearing mask - prob =  0.9925971
# user not wearing mask - prob =  0.990567
# user not wearing mask - prob =  0.9928149
# user not wearing mask - prob =  0.9126937
# user not wearing mask - prob =  0.9886608
# user not wearing mask - prob =  0.8950286
# user not wearing mask - prob =  0.9853255
# user not wearing mask - prob =  0.98066425
# user not wearing mask - prob =  0.6505384
# user not wearing mask - prob =  0.9656971
# user not wearing mask - prob =  0.5474386
# user not wearing mask - prob =  0.5336552
# user not wearing mask - prob =  0.95993876
# user not wearing mask - prob =  0.913956
# user not wearing mask - prob =  0.76003194
# user not wearing mask - prob =  0.8098989
# user not wearing mask - prob =  0.11924631
# user not wearing mask - prob =  0.35389534
# user not wearing mask - prob =  0.99877113
# user not wearing mask - prob =  0.5574241
# user not wearing mask - prob =  0.9243037
# user not wearing mask - prob =  0.99771667
# user not wearing mask - prob =  0.9502449
# user not wearing mask - prob =  0.8490846
# user not wearing mask - prob =  0.6717714
# user not wearing mask - prob =  0.9676482
# user not wearing mask - prob =  0.97948956
# user not wearing mask - prob =  0.6889888
# user not wearing mask - prob =  0.95150024
# user not wearing mask - prob =  0.9613017
# user not wearing mask - prob =  0.96819186
# user not wearing mask - prob =  0.97016317
# user not wearing mask - prob =  0.96840715
# user not wearing mask - prob =  0.76596934
# user not wearing mask - prob =  0.9743895
# user not wearing mask - prob =  0.959962
# user not wearing mask - prob =  0.9572461
# user not wearing mask - prob =  0.788714
# user not wearing mask - prob =  0.9576045
# user not wearing mask - prob =  0.7249158
# user not wearing mask - prob =  0.97297317
# user not wearing mask - prob =  0.9694472
# user not wearing mask - prob =  0.970867
# user not wearing mask - prob =  0.9572384
# user not wearing mask - prob =  0.7405081
# user not wearing mask - prob =  0.9588436
# user not wearing mask - prob =  0.97660875
# user not wearing mask - prob =  0.9757522
# user not wearing mask - prob =  0.97102904
# user not wearing mask - prob =  0.976153
# user not wearing mask - prob =  0.82941884
# user not wearing mask - prob =  0.9797896
# user not wearing mask - prob =  0.9726935
# user not wearing mask - prob =  0.67943126
# user not wearing mask - prob =  0.9683187
# user not wearing mask - prob =  0.97181386
# user not wearing mask - prob =  0.96871245
# user not wearing mask - prob =  0.99921274
# user not wearing mask - prob =  0.96331316
# user not wearing mask - prob =  0.7073642
# user not wearing mask - prob =  0.97159034
# user not wearing mask - prob =  0.79466903
# user not wearing mask - prob =  0.9768009
# user not wearing mask - prob =  0.9994431
# user not wearing mask - prob =  0.9753846
# user not wearing mask - prob =  0.963831
# user not wearing mask - prob =  0.72531676
# user not wearing mask - prob =  0.99927706
# user not wearing mask - prob =  0.62570184
# user not wearing mask - prob =  0.99930906
# user not wearing mask - prob =  0.9990785
# user not wearing mask - prob =  0.9882258
# user not wearing mask - prob =  0.97997266
# user not wearing mask - prob =  0.94251245
# user not wearing mask - prob =  0.8391694
# user not wearing mask - prob =  0.79010737
# user not wearing mask - prob =  0.37195468
# user not wearing mask - prob =  0.16260728
# user not wearing mask - prob =  0.11226423
# user not wearing mask - prob =  0.016588667
# user not wearing mask - prob =  0.009295319
# user not wearing mask - prob =  0.012841087
# user not wearing mask - prob =  0.017356092
# user not wearing mask - prob =  0.01454067
# user not wearing mask - prob =  0.050621074
# user not wearing mask - prob =  0.014973879
# user not wearing mask - prob =  0.025647929
# user not wearing mask - prob =  0.0143990405
# user not wearing mask - prob =  0.014748014
# user not wearing mask - prob =  0.014896587
# user not wearing mask - prob =  0.009978167
# user not wearing mask - prob =  0.006131614
# user not wearing mask - prob =  0.009339423
# user not wearing mask - prob =  0.01837328
# user not wearing mask - prob =  0.11096137
# user not wearing mask - prob =  0.2422637
# user not wearing mask - prob =  0.2409215
# user not wearing mask - prob =  0.23050018
# user not wearing mask - prob =  0.22360656
# user not wearing mask - prob =  0.27624848
# user not wearing mask - prob =  0.26220655
# user not wearing mask - prob =  0.2857731
# user not wearing mask - prob =  0.35497838
# user not wearing mask - prob =  0.28909567
# user not wearing mask - prob =  0.17566714
# user not wearing mask - prob =  0.19042856
# user not wearing mask - prob =  0.22996078
# user not wearing mask - prob =  0.24525285
# user not wearing mask - prob =  0.15372644
# user not wearing mask - prob =  0.18374202
# user not wearing mask - prob =  0.24701944
# user not wearing mask - prob =  0.9183611
# user not wearing mask - prob =  0.9425505
# user not wearing mask - prob =  0.9184477
# user not wearing mask - prob =  0.97412735
# user not wearing mask - prob =  0.99083054
# user not wearing mask - prob =  0.9922495
# user not wearing mask - prob =  0.992971
# user not wearing mask - prob =  0.994162
# user not wearing mask - prob =  0.9952708
# user not wearing mask - prob =  0.99403507
# user not wearing mask - prob =  0.99231637
# user not wearing mask - prob =  0.99281996
# user not wearing mask - prob =  0.992273
# user not wearing mask - prob =  0.09771876
# user not wearing mask - prob =  0.9912038
# user not wearing mask - prob =  0.99187416
# user not wearing mask - prob =  0.9984465
# user not wearing mask - prob =  0.9993699
# user not wearing mask - prob =  0.9992446
# user not wearing mask - prob =  0.9988268
# user not wearing mask - prob =  0.99915457
# user not wearing mask - prob =  0.9989311
# user not wearing mask - prob =  0.99915314
# user not wearing mask - prob =  0.99914503
# user not wearing mask - prob =  0.9991001
# user not wearing mask - prob =  0.99901605
# user not wearing mask - prob =  0.99908185
# user not wearing mask - prob =  0.9985404
# user not wearing mask - prob =  0.9981464
# user not wearing mask - prob =  0.9766996
# user not wearing mask - prob =  0.25243703
# user not wearing mask - prob =  0.022423357
# user not wearing mask - prob =  0.02883486
# user not wearing mask - prob =  0.024290225
# user not wearing mask - prob =  0.571379
# user not wearing mask - prob =  0.017125191
# user not wearing mask - prob =  0.045056723
# user not wearing mask - prob =  0.030170249
# user not wearing mask - prob =  0.025600106
# user not wearing mask - prob =  0.017206768
# user not wearing mask - prob =  0.016193023
# user not wearing mask - prob =  0.017697448
# user not wearing mask - prob =  0.017421672
# user not wearing mask - prob =  0.012709217
# user not wearing mask - prob =  0.009891498
# user not wearing mask - prob =  0.01072956
# user not wearing mask - prob =  0.012855792
# user not wearing mask - prob =  0.015310745
# user not wearing mask - prob =  0.019132433
# user not wearing mask - prob =  0.018008562
# user not wearing mask - prob =  0.45719334
# user not wearing mask - prob =  0.016220182
# user not wearing mask - prob =  0.014854763
# user not wearing mask - prob =  0.015332094
# user not wearing mask - prob =  0.015158487
# user not wearing mask - prob =  0.012252356
# user not wearing mask - prob =  0.016898125
# user not wearing mask - prob =  0.013450088
# user not wearing mask - prob =  0.015150123
# user not wearing mask - prob =  0.14472224
# user not wearing mask - prob =  0.3656201
# user not wearing mask - prob =  0.51475847
# user not wearing mask - prob =  0.9746893
# user not wearing mask - prob =  0.9391237
# user not wearing mask - prob =  0.9376437
# user not wearing mask - prob =  0.9934048
# user not wearing mask - prob =  0.99546826
# user not wearing mask - prob =  0.998415
# user not wearing mask - prob =  0.27199683
# user not wearing mask - prob =  0.9977852
# user not wearing mask - prob =  0.99829406
# user not wearing mask - prob =  0.9981267
# user not wearing mask - prob =  0.9982021
# user not wearing mask - prob =  0.9983944
# user not wearing mask - prob =  0.9987901
# user not wearing mask - prob =  0.99857235
# user not wearing mask - prob =  0.9986786
# user not wearing mask - prob =  0.99810314
# user not wearing mask - prob =  0.9986058
# user not wearing mask - prob =  0.9987565
# user not wearing mask - prob =  0.9991252
# user not wearing mask - prob =  0.9990447
# user not wearing mask - prob =  0.9987785
# user not wearing mask - prob =  0.9986407
# user not wearing mask - prob =  0.998692
# user not wearing mask - prob =  0.99875104
# user not wearing mask - prob =  0.99882513
# user not wearing mask - prob =  0.9988939
# user not wearing mask - prob =  0.9987417
# user not wearing mask - prob =  0.99895966
# user not wearing mask - prob =  0.99876547
# user not wearing mask - prob =  0.99899095
# user not wearing mask - prob =  0.99861705
# user not wearing mask - prob =  0.99879634
# user not wearing mask - prob =  0.99866796
# user not wearing mask - prob =  0.9984072
# user not wearing mask - prob =  0.99838495
# user not wearing mask - prob =  0.99874747
# user not wearing mask - prob =  0.99905187
# user not wearing mask - prob =  0.9991002
# user not wearing mask - prob =  0.9982566
# user not wearing mask - prob =  0.9983773
# user not wearing mask - prob =  0.998221
# user not wearing mask - prob =  0.9974342
# user not wearing mask - prob =  0.9970202
# user not wearing mask - prob =  0.9961514
# user not wearing mask - prob =  0.99686253
# user not wearing mask - prob =  0.99561596
# user not wearing mask - prob =  0.9967475
# user not wearing mask - prob =  0.9977034
# user not wearing mask - prob =  0.9978872
# user not wearing mask - prob =  0.99729913
# user not wearing mask - prob =  0.9982338
# user not wearing mask - prob =  0.9981178
# user not wearing mask - prob =  0.99688643
# user not wearing mask - prob =  0.99780875
# user not wearing mask - prob =  0.9974099
# user not wearing mask - prob =  0.9983829
# user not wearing mask - prob =  0.996521
# user not wearing mask - prob =  0.9971219
# user not wearing mask - prob =  0.99626017
# user not wearing mask - prob =  0.9967154
# user not wearing mask - prob =  0.9970324
# user not wearing mask - prob =  0.99633753
# user not wearing mask - prob =  0.99700755
# user not wearing mask - prob =  0.99491864
# user not wearing mask - prob =  0.9963754
# user not wearing mask - prob =  0.9967444
# user not wearing mask - prob =  0.99771595
# user not wearing mask - prob =  0.99727625
# user not wearing mask - prob =  0.99587715
# user not wearing mask - prob =  0.99766386
# user not wearing mask - prob =  0.9961281
# user not wearing mask - prob =  0.9974602
